# %% [markdown]
# # Figure out how to use python to blend a bunch of images
#
# See StackOverflow question [29106702](https://stackoverflow.com/questions/29106702/blend-overlapping-images-in-python)

# %%
from PIL import Image
from IPython.display import display

# %%
img1 = Image.open('../icons/action_icons/GLA/9.png')
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C68A310>

# %%
img2 = Image.open('../icons/action_icons/GLA/15.png')
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F207C75EB50>

# %%
img3 = Image.open('../icons/action_icons/GLA/16.png')
img3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C7A36A0>

# %%
print(img.format, img.size, img.mode)
# Out:
# PNG (40, 40) RGBA

# %%
img12 = Image.blend(img1, img2, 1/2)
img12
# Out:
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C5C8400>

# %%
img123 = Image.blend(img12, img3, 1/3)
img123
# Out:
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C5C83A0>

# %% [markdown]
# ## Try this with all GLA images
# Can blend 2 at a time, reblending previously blended image as long as we weight the blending in the right way. Specifically, can set the weight fraction to 1 / n for the nth blended image.

# %%
blended_image = None
for i, img_id in enumerate([9, 15, 16, 17, 20, 21, 23, 23, 28, 7381]):
    img_uri = f'../icons/action_icons/GLA/{img_id}.png'
    img = Image.open(img_uri)
    if not blended_image:
        blended_image = img
    else:
        blended_image = Image.blend(blended_image, img, 1 / (i + 1))
    display(img, blended_image)
    print('\n')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5AF460>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5AF460>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5AF130>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C7A3700>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5AF460>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C5AA340>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5AF130>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F207C7265B0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5AF460>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C7A3700>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5AFB20>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F207C7265B0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5AF460>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C5AA340>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5AFB20>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C7A3700>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5AF460>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F207C7265B0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5AFB20>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C5AA340>

# %% [markdown]
# ### Try blending the images in reverse order, image should be same

# %%
blended_image2 = None
for i, img_id in enumerate([9, 15, 16, 17, 20, 21, 23, 23, 28, 7381][::-1]):
    img_uri = f'../icons/action_icons/GLA/{img_id}.png'
    img = Image.open(img_uri)
    if not blended_image2:
        blended_image2 = img
    else:
        blended_image2 = Image.blend(blended_image2, img, 1 / (i + 1))
    display(img, blended_image2)
    print('\n')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206CD2EF70>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206CD2EF70>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5C8790>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C5C8B20>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5C8D30>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206CD2EF70>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5C8310>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C5C84C0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5C87C0>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206CD2EF70>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5C85B0>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C5C82B0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5C8B20>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206CD2EF70>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5C8D30>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C5C84C0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5C85B0>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C7A3700>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x40 at 0x7F206C5C82B0>
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C5C8D30>

# %% [markdown]
# ## Check

# %%
blended_image
# Out:
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C5AA340>

# %%
blended_image2
# Out:
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C5C8D30>

# %% [markdown]
# ## Looks the same to me!

# %% [markdown]
# ## What if we layer class job icon on top of blended image?

# %%
cj_icon = Image.open('../icons/class_job_icons/GLA.png')
cj_icon
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256 at 0x7F206C593A60>

# %%
# First make same size as blended image
cj_icon = cj_icon.resize((40, 40))
cj_icon
# Out:
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C593B20>

# %%
blended_image.paste(cj_icon, (0, 0), cj_icon)

# %%
blended_image
# Out:
# <PIL.Image.Image image mode=RGBA size=40x40 at 0x7F206C5AA340>
